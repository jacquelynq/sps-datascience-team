# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/jacquelynq/sps-datascience-team/blob/master/pandas_and_seaborn_plotting.ipynb)

# %%
# !git clone https://github.com/jacquelynq/sps-datascience-team.git
# Out:
# Cloning into 'sps-datascience-team'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 11 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %%
# !pip install -q xlrd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !ls sps-datascience-team
# Out:
# astrost17.xlsx
# pandas_and_seaborn_plotting.ipynb
# physrostr17.xlsx
# README.md
# US_graduate_schools_admission_parameters_dataset.csv

# %%
programs = pd.read_excel('sps-datascience-team/physrostr17.xlsx')
admin_params = pd.read_csv('sps-datascience-team/US_graduate_schools_admission_parameters_dataset.csv')
admin_params
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
#plots the minimum GRE Score vs. University ranking
fig, ax = plt.subplots()
ax.scatter(admin_params['GRE Score'], admin_params['University Rating'])
plt.show()

# %%
fig, ax = plt.subplots()
plt.scatter(admin_params['Chance of Admit '], admin_params['GRE Score'])
sns.regplot(admin_params['Chance of Admit '], admin_params['GRE Score'])

# %%
fig, ax = plt.subplots()

ax = sns.regplot(admin_params['Chance of Admit '], admin_params['GRE Score'])
